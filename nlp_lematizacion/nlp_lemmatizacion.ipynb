# %% [markdown]
# ### Lemmatizacion

# %% [markdown]
# #### Instalación y Obtención de datos

# %% [markdown]
# - Instalaciones

# %%
# !pip install spacy wordcloud matplotlib scikit-learn
# !pip install nltk
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# Out:
# Requirement already satisfied: spacy in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (3.8.5)
# Requirement already satisfied: wordcloud in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: scikit-learn in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: pillow in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\eduardo\desktop\entonotensorflow\.venv\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting es-core-news-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# - Importaciónes

# %%
import pandas as pd
import spacy
import nltk
import re
from nltk.corpus import stopwords, wordnet
from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
import matplotlib.pyplot as plt

# %% [markdown]
# - Descargar recursos NLTK

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Eduardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Eduardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Eduardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Eduardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# - Cargar los recursos de spaCy

# %%
# Cargar modelos de spaCy
nlp_es = spacy.load('es_core_news_sm')
nlp_en = spacy.load('en_core_web_sm')
stopwords_es = set(stopwords.words('spanish'))
stopwords_en = set(stopwords.words('english'))

lemmatizer_en = WordNetLemmatizer()

# %% [markdown]
# - Obtención de datos

# %%
# Ruta al archivo CSV
ruta_csv = './reviews_multilang.csv'

# Cargar los datos correctamente especificando el separador
df = pd.read_csv(
    ruta_csv,
    sep=',',
    engine='python',      # Usamos el motor más flexible
    on_bad_lines='skip'   # Esta es la opción válida actualmente
)

# Mostrar las primeras filas
df.head()
# Out:
#                                                texto idioma sentimiento
# 0  La interfaz intuitiva facilita la navegación i...     es    positivo
# 1  El rendimiento gráfico dejó mucho que desear e...     es    negativo
# 2  Constantes fallos de conectividad WiFi tras la...     es    negativo
# 3  Sorprendido por la autonomía de la batería en ...     es    positivo
# 4  El sistema operativo se bloquea recurrentement...     es    negativo

# %% [markdown]
# - Crear la función lematizar(texto, idioma)

# %%
def nltk_pos_tag_to_wordnet(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def lematizar(texto, idioma):
    if idioma == 'es':
        doc = nlp_es(texto.lower())
        return ' '.join([token.lemma_ for token in doc if token.is_alpha and token.lemma_ not in stopwords_es])
    elif idioma == 'en':
        tokens = word_tokenize(texto.lower())
        tagged = pos_tag(tokens)
        lemas = [lemmatizer_en.lemmatize(token, nltk_pos_tag_to_wordnet(tag)) for token, tag in tagged]
        return ' '.join([lema for lema in lemas if lema.isalpha() and lema not in stopwords_en])
    else:
        return texto

# %% [markdown]
# - Implemetancion del Lematizador

# %%
df['lemas'] = df.apply(lambda fila: lematizar(fila['texto'], fila['idioma']), axis=1)

# %% [markdown]
# #### Fase 2: Detección de Términos Técnicos y Jerga

# %%
# Lista personalizada de jergas técnicas
jerga_tecnica = {
    r'\bcrashe[oó]\b': 'crashear',
    r'\bbuguead[oa]\b': 'bugueado',
    r'\bfreez(e|ed|ing)\b': 'freeze',
    r'\bglitche[ds]?\b': 'glitch',
    r'\blague[ao]\b': 'lag'
}

def normalizar_jerga(texto):
    for patron, reemplazo in jerga_tecnica.items():
        texto = re.sub(patron, reemplazo, texto, flags=re.IGNORECASE)
    return texto

# Aplicar normalización a columna de lemas
df['lemas'] = df['lemas'].apply(normalizar_jerga)

# %% [markdown]
# #### Fase 3: Modelo de Clasificación y Comparación

# %%
# Codificar el target
df['sentimiento_binario'] = df['sentimiento'].map({'positivo': 1, 'negativo': 0})

# Comparar usando texto original vs texto lematizado
X_raw = df['texto']
X_lem = df['lemas']
y = df['sentimiento_binario']

# Vectorizar y dividir
vectorizer_raw = TfidfVectorizer()
vectorizer_lem = TfidfVectorizer()

X_raw_vec = vectorizer_raw.fit_transform(X_raw)
X_lem_vec = vectorizer_lem.fit_transform(X_lem)

X_train_raw, X_test_raw, y_train, y_test = train_test_split(X_raw_vec, y, test_size=0.2, random_state=42)
X_train_lem, X_test_lem, _, _ = train_test_split(X_lem_vec, y, test_size=0.2, random_state=42)

# Entrenar y evaluar
clf_raw = RandomForestClassifier(random_state=42)
clf_lem = RandomForestClassifier(random_state=42)

clf_raw.fit(X_train_raw, y_train)
clf_lem.fit(X_train_lem, y_train)

pred_raw = clf_raw.predict(X_test_raw)
pred_lem = clf_lem.predict(X_test_lem)

f1_raw = f1_score(y_test, pred_raw)
f1_lem = f1_score(y_test, pred_lem)

print("F1-score SIN lematización:", f1_raw)
print("F1-score CON lematización:", f1_lem)

# Tamaño de vocabulario
print("Tamaño vocabulario original:", len(vectorizer_raw.vocabulary_))
print("Tamaño vocabulario lematizado:", len(vectorizer_lem.vocabulary_))
# Out:
# F1-score SIN lematización: 0.6
# F1-score CON lematización: 0.5714285714285714
# Tamaño vocabulario original: 276
# Tamaño vocabulario lematizado: 243

# %% [markdown]
# #### Fase 4: Evaluación Comparativa

# %%
# Reducción de vocabulario
vocab_reduccion = 100 * (1 - len(vectorizer_lem.vocabulary_) / len(vectorizer_raw.vocabulary_))
print(f"Reducción del vocabulario: {vocab_reduccion:.2f}%")

# Mejora de F1
f1_mejora = 100 * (f1_lem - f1_raw) / f1_raw
print(f"Mejora de F1-score: {f1_mejora:.2f}%")

# Análisis de negaciones comunes
negaciones = ['no', 'nunca', 'jamás', 'sin']
contador_neg = Counter()

for texto in df['lemas']:
    for palabra in texto.split():
        if palabra in negaciones:
            contador_neg[palabra] += 1

print("Palabras negativas más comunes:", contador_neg)
# Out:
# Reducción del vocabulario: 11.96%
# Mejora de F1-score: -4.76%
# Palabras negativas más comunes: Counter()

# %% [markdown]
# - Resultados finales

# %%
df.head(50)
# Out:
#                                                 texto idioma sentimiento  \
# 0   La interfaz intuitiva facilita la navegación i...     es    positivo
# 1   El rendimiento gráfico dejó mucho que desear e...     es    negativo
# 2   Constantes fallos de conectividad WiFi tras la...     es    negativo
# 3   Sorprendido por la autonomía de la batería en ...     es    positivo
# 4   El sistema operativo se bloquea recurrentement...     es    negativo
# 5   Calidad de construcción premium que justifica ...     es    positivo
# 6   El micrófono incorporado tiene una sensibilida...     es    negativo
# 7   Actualizaciones frecuentes que realmente mejor...     es    positivo
# 8   El sensor de huellas demora hasta 3 segundos e...     es    negativo
# 9   Ergonomía excepcional para sesiones prolongada...     es    positivo
# 10  El altavoz principal distorsiona los graves a ...     es    negativo
# 11  Reconocimiento facial funciona incluso con baj...     es    positivo
# 12  El sobrecalentamiento persiste durante videoll...     es    negativo
# 13  El diseño modular permite actualizaciones futu...     es    positivo
# 14  La cámara frontal suaviza excesivamente los de...     es    negativo
# 15  El software de gestión de energía optimiza not...     es    positivo
# 16  El panel táctil registra clics fantasmas de ma...     es    negativo
# 17  La función de carga rápida supera las especifi...     es    positivo
# 18  Los controladores periféricos presentan incomp...     es    negativo
# 19  La pantalla HDR ofrece negros profundos y colo...     es    positivo
# 20  Bluetooth 5.3 mantiene conexión estable hasta ...     es    positivo
# 21  El sistema de refrigeración genera ruido moles...     es    negativo
# 22  La corrección automática de texto subestima mi...     es    negativo
# 23  La resistencia al agua IP68 fue verificada sat...     es    positivo
# 24  El asistente virtual interpreta incorrectament...     es    negativo
# 25  Excepcional relación calidad-precio en su cate...     es    positivo
# 26  El módulo 5G consume batería de manera desprop...     es    negativo
# 27  Los perfiles personalizados de sonido enriquec...     es    positivo
# 28  La cubierta anti-reflejos reduce eficazmente e...     es    positivo
# 29  El proceso de devolución resultó engorroso y b...     es    negativo
# 30  El reconocimiento de voz transcribe con 98% de...     es    positivo
# 31  La bisagra presenta holgura tras apenas dos me...     es    negativo
# 32  Actualización de firmware resolvió problemas d...     es    positivo
# 33  El sistema de reconocimiento facial falla con ...     es    negativo
# 34  La función multitarea gestiona eficientemente ...     es    positivo
# 35  El micrófono no filtra adecuadamente el ruido ...     es    negativo
# 36  La pantalla táctil responde con precisión mili...     es    positivo
# 37  El módulo GPS tarda 45 segundos en fijar posic...     es    negativo
# 38  La conectividad Thunderbolt 4 permite transfer...     es    positivo
# 39  El software preinstalado incluye bloatware dif...     es    negativo
# 40  El sistema de sonido Dolby Atmos crea una envo...     es    positivo
# 41  La cámara térmica identifica componentes sobre...     es    positivo
# 42  El teclado mecánico ofrece retroalimentación t...     es    positivo
# 43  La compatibilidad con legacy systems requiere ...     es    negativo
# 44  El modo oscuro automático se ajusta inteligent...     es    positivo
# 45  El sensor de huellas requiere recalibración se...     es    negativo
# 46  La realidad aumentada integrada supera expecta...     es    positivo
# 47  El proceso de autenticación biométrica consume...     es    negativo
#
#                                                 lemas  sentimiento_binario
# 0   interfaz intuitivo facilitar navegación inclus...                    1
# 1     rendimiento gráfico dejar desear juego exigente                    0
# 2   constante fallo conectividad wifi tras último ...                    0
# 3    sorprendido autonomía batería modo uso intensivo                    1
# 4   sistema operativo bloquear recurrentemente eje...                    0
# 5   calidad construcción premium justificar precio...                    1
# 6   micrófono incorporado tener sensibilidad defic...                    0
# 7   actualización frecuente realmente mejorar expe...                    1
# 8         sensor huella demoro segundo reconocer dedo                    0
# 9     ergonomía excepcional sesión prolongado trabajo                    1
# 10  altavoz principal distorsionar grave volumen m...                    0
# 11  reconocimiento facial funcionar incluso bajo i...                    1
# 12  sobrecalentamiento persistir videollamada extenso                    0
# 13  diseño modular permitir actualización futuro c...                    1
# 14  cámara frontal suavizar excesivamente detalle ...                    0
# 15  software gestión energía optimizo notablemente...                    1
# 16  panel táctil registrar clics fantasma manera i...                    0
# 17  función carga rápido superar especificación an...                    1
# 18  controlador periférico presentar incompatibili...                    0
# 19  pantalla hdr ofrecer negro profundo color vibr...                    1
# 20  bluetooth mantener conexión estable metro dist...                    1
# 21  sistema refrigeración generar ruido molesto ba...                    0
# 22  corrección automático texto subestima vocabula...                    0
# 23  resistencia agua ser verificar satisfactoriame...                    1
# 24  asistente virtual interpretar incorrectamente ...                    0
# 25          excepcional relación categoría gama medio                    1
# 26  módulo g consumir batería manera desproporcionado                    0
# 27  perfil personalizado sonido enriquecer experie...                    1
# 28      cubierta reducir eficazmente cansancio visual                    1
# 29  proceso devolución resultar engorroso burocrático                    0
# 30  reconocimiento voz transcribir precisión diale...                    1
# 31  bisagra presentar holgura tras apenas dos mes ...                    0
# 32  actualización firmware resolver problema laten...                    1
# 33  sistema reconocimiento facial fallar accesorio...                    0
# 34  función multitareo gestionar eficientemente ap...                    1
# 35  micrófono filtrar adecuadamente ruido ambienta...                    0
# 36  pantalla táctil responder precisión milimétric...                    1
# 37  módulo gps tardar segundo fijar posición interior                    0
# 38  conectividad thunderbolt permitir transferenci...                    1
# 39  software preinstalado incluir bloatware difíci...                    0
# 40  sistema sonido dolby atmo creer envolvente inm...                    1
# 41  cámara térmico identificar componente sobrecal...                    1
# 42  teclado mecánico ofrecer retroalimentación tác...                    1
# 43  compatibilidad legacy systems requerir control...                    0
# 44  modo oscuro automático ajustar inteligentement...                    1
# 45  sensor huella requerir recalibración semanal m...                    0
# 46  realidad aumentado integrado superar expectati...                    1
# 47  proceso autenticación biométrico consumir recu...                    0
